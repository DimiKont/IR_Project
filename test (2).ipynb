# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import string

# %%
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /Users/tsomi/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/tsomi/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# ## Βήμα 1: Συλλογή Δεδομένων
# Τα δεδομένα που χρησιμοποιήθηκαν για την υλοποίηση της εργασίας είναι βρίσκονται στον εξής σύνδεσμο: https://www.kaggle.com/datasets/sameersmahajan/people-wikipedia-data

# %%
df = pd.read_csv('in/pure_people_wiki.csv')

stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

# %% [markdown]
# ## Βήμα 2. Προεπεξεργασία κειμένου (Text Processing):

# %%
def tokenize(text):
    return text.split()

def remove_punctuation(words):
    cleaned_words = []
    for word in words:
        if word not in string.punctuation:
            cleaned_words.append(word)
    return cleaned_words

def filter_stop_words(words):
    filtered_words = []
    for word in words:
        if word not in stop_words:
            filtered_words.append(word)
    return filtered_words

def lemmatize_words(words):
    return [lemmatizer.lemmatize(word) for word in words]

def preprocess_text(text):
    tokens = tokenize(text)                      # Step 1: Tokenization
    tokens = remove_punctuation(tokens)          # Step 2: Remove Punctuation
    tokens = filter_stop_words(tokens)           # Step 3: Remove Stop Words
    lemmatized_tokens = lemmatize_words(tokens)  # Step 4: Lemmatization
    return lemmatized_tokens

# Apply preprocessing to each text entry
df['processed_text'] = df['text'].apply(preprocess_text)

# Display the processed DataFrame
print(df[['URI', 'name', 'processed_text']].head())
# Out:
#                                                URI                 name  \
# 0        http://dbpedia.org/resource/Digby_Morrell        Digby Morrell
# 1       http://dbpedia.org/resource/Alfred_J._Lewy       Alfred J. Lewy
# 2        http://dbpedia.org/resource/Harpdog_Brown        Harpdog Brown
# 3  http://dbpedia.org/resource/Franz_Rottensteiner  Franz Rottensteiner
# 4               http://dbpedia.org/resource/G-Enka               G-Enka
#
#                                       processed_text
# 0  [digby, morrell, born, 10, october, 1979, form...
# 1  [alfred, j, lewy, aka, sandy, lewy, graduated,...
# 2  [harpdog, brown, singer, harmonica, player, ac...
# 3  [franz, rottensteiner, born, waidmannsfeld, lo...
# 4  [henry, krvits, born, 30, december, 1974, tall...

# %% [markdown]
# ## Βήμα 3: Ευρετήριο (Indexing)
# ### α. Δημιουργία inverted index

# %%
corpus = {}

# Do the same for the first 1000 entries
# We enumerate the URI column of the dataframe so we can index it.
# Then we take its list of tokens and we count the amount of times each token appears
for i, uri in enumerate(df['URI'][:1000]):
    corpus[uri] = {tok: df['processed_text'][i].count(tok) for tok in df['processed_text'][i]}

# revert it back to a dataframe
df = pd.DataFrame.from_records(corpus).fillna(0).astype(int).T
df[df.columns]
# Out:
#                                                     aaron  lacrate  american  \
# http://dbpedia.org/resource/Aaron_LaCrate               5       12         1
# http://dbpedia.org/resource/Abdel_Fattah_el-Sisi        0        0         0
# http://dbpedia.org/resource/Abdul_Salam_Azimi           0        0         0
# http://dbpedia.org/resource/Abdulalim_A._Shabazz        0        0         4
# http://dbpedia.org/resource/Abu_Mustafa_al-Shei...      0        0         0
# ...                                                   ...      ...       ...
# http://dbpedia.org/resource/Yolande_Thibeault           0        0         0
# http://dbpedia.org/resource/Yoshi_Wada                  0        0         0
# http://dbpedia.org/resource/Yoshihisa_Naruse            0        0         0
# http://dbpedia.org/resource/Zahid_Al-Sheikh             0        0         0
# http://dbpedia.org/resource/Zuenir_Ventura              0        0         0
#
#                                                     music  producer  \
# http://dbpedia.org/resource/Aaron_LaCrate               7         1
# http://dbpedia.org/resource/Abdel_Fattah_el-Sisi        0         0
# http://dbpedia.org/resource/Abdul_Salam_Azimi           0         0
# http://dbpedia.org/resource/Abdulalim_A._Shabazz        0         0
# http://dbpedia.org/resource/Abu_Mustafa_al-Shei...      0         0
# ...                                                   ...       ...
# http://dbpedia.org/resource/Yolande_Thibeault           0         0
# http://dbpedia.org/resource/Yoshi_Wada                  1         0
# http://dbpedia.org/resource/Yoshihisa_Naruse            0         0
# http://dbpedia.org/resource/Zahid_Al-Sheikh             0         0
# http://dbpedia.org/resource/Zuenir_Ventura              0         0
#
#                                                     recording  artist  dj  \
# http://dbpedia.org/resource/Aaron_LaCrate                   2       2   3
# http://dbpedia.org/resource/Abdel_Fattah_el-Sisi            0       0   0
# http://dbpedia.org/resource/Abdul_Salam_Azimi               0       0   0
# http://dbpedia.org/resource/Abdulalim_A._Shabazz            0       0   0
# http://dbpedia.org/resource/Abu_Mustafa_al-Shei...          0       0   0
# ...                                                       ...     ...  ..
# http://dbpedia.org/resource/Yolande_Thibeault               0       0   0
# http://dbpedia.org/resource/Yoshi_Wada                      1       1   0
# http://dbpedia.org/resource/Yoshihisa_Naruse                0       0   0
# http://dbpedia.org/resource/Zahid_Al-Sheikh                 0       0   0
# http://dbpedia.org/resource/Zuenir_Ventura                  0       0   0
#
#                                                     fashion  designer  ...  \
# http://dbpedia.org/resource/Aaron_LaCrate                 5         2  ...
# http://dbpedia.org/resource/Abdel_Fattah_el-Sisi          0         0  ...
# http://dbpedia.org/resource/Abdul_Salam_Azimi             0         0  ...
# http://dbpedia.org/resource/Abdulalim_A._Shabazz          0         0  ...
# http://dbpedia.org/resource/Abu_Mustafa_al-Shei...        0         0  ...
# ...                                                     ...       ...  ...
# http://dbpedia.org/resource/Yolande_Thibeault             0         0  ...
# http://dbpedia.org/resource/Yoshi_Wada                    0         0  ...
# http://dbpedia.org/resource/Yoshihisa_Naruse              0         0  ...
# http://dbpedia.org/resource/Zahid_Al-Sheikh               0         0  ...
# http://dbpedia.org/resource/Zuenir_Ventura                0         0  ...
#
#                                                     investigationzuenir  \
# http://dbpedia.org/resource/Aaron_LaCrate                             0
# http://dbpedia.org/resource/Abdel_Fattah_el-Sisi                      0
# http://dbpedia.org/resource/Abdul_Salam_Azimi                         0
# http://dbpedia.org/resource/Abdulalim_A._Shabazz                      0
# http://dbpedia.org/resource/Abu_Mustafa_al-Shei...                    0
# ...                                                                 ...
# http://dbpedia.org/resource/Yolande_Thibeault                         0
# http://dbpedia.org/resource/Yoshi_Wada                                0
# http://dbpedia.org/resource/Yoshihisa_Naruse                          0
# http://dbpedia.org/resource/Zahid_Al-Sheikh                           0
# http://dbpedia.org/resource/Zuenir_Ventura                            1
#
#                                                     janitor  denture  \
# http://dbpedia.org/resource/Aaron_LaCrate                 0        0
# http://dbpedia.org/resource/Abdel_Fattah_el-Sisi          0        0
# http://dbpedia.org/resource/Abdul_Salam_Azimi             0        0
# http://dbpedia.org/resource/Abdulalim_A._Shabazz          0        0
# http://dbpedia.org/resource/Abu_Mustafa_al-Shei...        0        0
# ...                                                     ...      ...
# http://dbpedia.org/resource/Yolande_Thibeault             0        0
# http://dbpedia.org/resource/Yoshi_Wada                    0        0
# http://dbpedia.org/resource/Yoshihisa_Naruse              0        0
# http://dbpedia.org/resource/Zahid_Al-Sheikh               0        0
# http://dbpedia.org/resource/Zuenir_Ventura                1        1
#
#                                                     officeboy  universityhis  \
# http://dbpedia.org/resource/Aaron_LaCrate                   0              0
# http://dbpedia.org/resource/Abdel_Fattah_el-Sisi            0              0
# http://dbpedia.org/resource/Abdul_Salam_Azimi               0              0
# http://dbpedia.org/resource/Abdulalim_A._Shabazz            0              0
# http://dbpedia.org/resource/Abu_Mustafa_al-Shei...          0              0
# ...                                                       ...            ...
# http://dbpedia.org/resource/Yolande_Thibeault               0              0
# http://dbpedia.org/resource/Yoshi_Wada                      0              0
# http://dbpedia.org/resource/Yoshihisa_Naruse                0              0
# http://dbpedia.org/resource/Zahid_Al-Sheikh                 0              0
# http://dbpedia.org/resource/Zuenir_Ventura                  1              1
#
#                                                     tribuna  imprensa  \
# http://dbpedia.org/resource/Aaron_LaCrate                 0         0
# http://dbpedia.org/resource/Abdel_Fattah_el-Sisi          0         0
# http://dbpedia.org/resource/Abdul_Salam_Azimi             0         0
# http://dbpedia.org/resource/Abdulalim_A._Shabazz          0         0
# http://dbpedia.org/resource/Abu_Mustafa_al-Shei...        0         0
# ...                                                     ...       ...
# http://dbpedia.org/resource/Yolande_Thibeault             0         0
# http://dbpedia.org/resource/Yoshi_Wada                    0         0
# http://dbpedia.org/resource/Yoshihisa_Naruse              0         0
# http://dbpedia.org/resource/Zahid_Al-Sheikh               0         0
# http://dbpedia.org/resource/Zuenir_Ventura                1         1
#
#                                                     lacerda  managerowner  \
# http://dbpedia.org/resource/Aaron_LaCrate                 0             0
# http://dbpedia.org/resource/Abdel_Fattah_el-Sisi          0             0
# http://dbpedia.org/resource/Abdul_Salam_Azimi             0             0
# http://dbpedia.org/resource/Abdulalim_A._Shabazz          0             0
# http://dbpedia.org/resource/Abu_Mustafa_al-Shei...        0             0
# ...                                                     ...           ...
# http://dbpedia.org/resource/Yolande_Thibeault             0             0
# http://dbpedia.org/resource/Yoshi_Wada                    0             0
# http://dbpedia.org/resource/Yoshihisa_Naruse              0             0
# http://dbpedia.org/resource/Zahid_Al-Sheikh               0             0
# http://dbpedia.org/resource/Zuenir_Ventura                1             1
#
#                                                     camus
# http://dbpedia.org/resource/Aaron_LaCrate               0
# http://dbpedia.org/resource/Abdel_Fattah_el-Sisi        0
# http://dbpedia.org/resource/Abdul_Salam_Azimi           0
# http://dbpedia.org/resource/Abdulalim_A._Shabazz        0
# http://dbpedia.org/resource/Abu_Mustafa_al-Shei...      0
# ...                                                   ...
# http://dbpedia.org/resource/Yolande_Thibeault           0
# http://dbpedia.org/resource/Yoshi_Wada                  0
# http://dbpedia.org/resource/Yoshihisa_Naruse            0
# http://dbpedia.org/resource/Zahid_Al-Sheikh             0
# http://dbpedia.org/resource/Zuenir_Ventura              1
#
# [1000 rows x 31294 columns]

# %% [markdown]
# ### β. Αποθήκευση του Inverted Index σε .csv αρχείο

# %%
# save the dataframe to a csv file
df.to_csv('out/results.csv', index = True)

# %% [markdown]
# Μετατροπή του .csv αρχείου σε dictionary

# %%
df = pd.read_csv('out/results.csv') # read the csv file
df.set_index(df.columns[0], inplace=True) # set the first column as the index
# print(df)

data_dict = df.to_dict(orient='index') # Convert DataFrame to dictionary
# Print the first 5 entries of the dictionary
for uri, terms in list(data_dict.items())[:5]:
    print(f"Document URI: {uri}, Terms: {terms}")
# Out:
# Document URI: http://dbpedia.org/resource/Aaron_LaCrate, Terms: {'aaron': 5, 'lacrate': 12, 'american': 1, 'music': 7, 'producer': 1, 'recording': 2, 'artist': 2, 'dj': 3, 'fashion': 5, 'designer': 2, 'milkcrate': 6, 'record': 4, 'clothing': 2, 'film': 1, 'director': 1, 'born': 1, 'baltimore': 9, 'maryland': 1, 'grew': 1, 'highlandtown': 1, 'east': 1, 'baltimoreaaron': 1, 'credited': 2, 'popularizing': 1, 'culture': 2, 'world': 1, 'wide': 1, 'level': 1, 'via': 1, '2009': 1, 'produced': 3, 'first': 7, 'ever': 1, 'club': 2, 'platinum': 1, 'pop': 1, 'star': 1, 'dizzee': 3, 'rascal': 3, 'song': 1, 'road': 1, 'ragehbo': 1, 'commissioned': 2, 'athletics': 3, 'create': 1, 'official': 2, 'range': 1, 'based': 1, 'cable': 1,
 0, 'rick': 0, 'upon': 0, 'released': 0, 'prison': 0, 'outkast': 0, 'wutang': 0, 'clan': 0, 'epmd': 0, 'ultramagnetic': 0, 'mc': 0, 'many': 0, 'historical': 0, 'performanceslacrate': 0, 'remixed': 0, 'major': 0, 'label': 0, 'madonna': 0, 'gorillaz': 0, 'soulja': 0, 'boy': 0, 'tell': 0, 'em': 0, 'young': 0, 'cool': 0, 'kid': 0, 'track': 0, 'lacrates': 0, 'album': 0, 'bmore': 0, 'gutter': 0, '2005': 2, 'used': 1, 'marc': 0, 'jacob': 0, 'showlacrate': 0, 'toured': 0, 'mark': 0, 'ronson': 0, 'recently': 0, 'kanye': 0, 'west': 0, 'developed': 0, 'specialedition': 0, 'van': 0, 'colette': 0, 'paris': 0, 'jayz': 0, 'cashmere': 0, 'king': 0, 'lucien': 0, 'pellatfinet': 0, 'cocacola': 0, 'delicious': 0, 'vinyl': 0, 'dazed': 0, 'confused': 0, 'ferrariwhich': 0, 'ferrari': 0, 'featured': 0, 'entourage': 0, 'support': 0, 'hero': 0, 'videogame': 0, 'soundtrack': 0, 'observe': 0, 'report': 0, 'starring': 0, 'seth': 0, 'rogenrecently': 0, 'crack': 0, 'feature': 0, 'mr': 0, 'vega': 0, 'doolittle': 0, 'local': 0, 'including': 0, 'mz': 0, 'streamz': 0, 'verb': 0, 'abdel': 0, 'fattah': 0, 'saeed': 0, 'hussein': 1, 'khalil': 0, 'elsisi': 0, 'arabic': 0, 'abdu': 0, 'lfatt': 0, 'sad': 0, 'usayn': 0, 'khall': 0, 'ass': 0, 'ipa': 0, 'bdelftt': 0, 'sid': 0, 'esen': 0, 'xlil': 0, 'essisi': 0, '19': 0, 'november': 0, '1954': 0, 'sixth': 0, 'current': 0, 'president': 0, 'egypt': 0, 'office': 0, 'since': 0, '2014born': 0, 'gamaleya': 0, 'old': 0, 'cairo': 0, 'sisi': 0, 'graduated': 0, 'egyptian': 0, 'military': 0, 'academy': 0, 'u': 1, 'army': 0, 'war': 0, 'college': 0, 'held': 0, 'various': 0, 'command': 2, 'position': 0, 'armed': 0, 'force': 5, 'served': 0, 'attach': 0, 'riyadh': 0, 'got': 0, 'bachelor': 0, 'science': 0, '1977': 0, 'master': 0, 'staff': 0, '1987': 0, 'joint': 0, 'service': 0, 'uk': 0, '1992': 0, 'addition': 0, 'fellowshipsisi': 0, 'member': 1, 'scaf': 0, 'revolution': 1, '2011': 0, 'serving': 0, 'intelligence': 0, 'reconnaissance': 0, 'departmen ...

# %% [markdown]
# ## 4. Μηχανή Αναζήτησης
# ### α. Επεξεργασία Ερωτήματος (Query Processing)

# %%
def search_query_dict(data_dict, query):
    tokens = query.split()  # Split the query into separate tokens
    print("Tokenized query: ", tokens)

    initial_term = tokens[0].lower()  # Retrieve the first term

    # Ensure the initial term exists in the data_dict
    if initial_term not in next(iter(data_dict.values())):  # Check the terms in the first document
        print(f"Term '{initial_term}' not found in the documents.")
        return []

    # Get URIs for the initial term (those documents where the term has a frequency > 0)
    results = {uri for uri, terms in data_dict.items() if terms.get(initial_term, 0) > 0}
    combined_results = results


    # Process additional terms with Boolean operators (AND, OR, NOT)
    i = 1
    while i < len(tokens):
        operator = tokens[i].upper()
        term = tokens[i + 1].lower()

        # Ensure the term exists in the data
        if term not in next(iter(data_dict.values())):
            print(f"Term '{term}' not found in the documents.")
            return []

        # Get URIs for the current term (those documents where the term has a frequency > 0)
        term_uris = {uri for uri, terms in data_dict.items() if terms.get(term, 0) > 0}

        # Apply the Boolean operators
        if operator == "AND":
            combined_results &= term_uris  # Intersection for AND
        elif operator == "OR":
            combined_results |= term_uris  # Union for OR
        elif operator == "NOT":
            combined_results -= term_uris  # Difference for NOT

        i += 2  # Move to the next pair

    #print(f"Combined result URIs: {combined_results}")
    return combined_results

# %% [markdown]
# **Εκτέλεση Boolean Query και εμφάνιση πλήθους αποτελεσμάτων (χωρίς κατάταξη)**

# %%
# Test the search_query_dict function with a boolean query (without ranking)
query = "musician AND jazz"
matching_uris = search_query_dict(data_dict, query)
print("Number of matching URIs: ", len(matching_uris))
# Out:
# Tokenized query:  ['musician', 'AND', 'jazz']
# Number of matching URIs:  18

# %% [markdown]
# ### β. Κατάταξη αποτελεσμάτων

# %%
# Dictionary to store the scores
def search_query_dict_ranked(data_dict, query):
    combined_results = search_query_dict(data_dict, query)
    tokens = query.split()
    scores = {uri: 0 for uri in combined_results}

    # Calculate scores for the documents in the combined results
    for uri in combined_results:
        scores[uri] = sum(data_dict[uri].get(token.lower(), 0) for token in tokens if token.isalnum())

    # Sort documents by score in descending order
    ranked_results = sorted(combined_results, key=lambda uri: scores[uri], reverse=True)

    # Create a user-friendly formatted output
    print("\nSearch Results:")
    print("-" * 40)
    if not ranked_results:
        print("No matching documents found.")
    else:
        print("{:<6} {:<20} {:<10}".format("Rank", "Document", "Score"))
        print("-" * 40)
        for rank, uri in enumerate(ranked_results, start=1):
            print("{:<6} {:<20} {:<10}".format(rank, uri, scores[uri]))
        print("-" * 40)

    # Return the ranked list of matching URIs
    return ranked_results

# %%
import math
from collections import defaultdict

# Compute TF-IDF weights
def compute_tf_idf(data_dict):
    doc_count = len(data_dict)
    term_doc_frequency = defaultdict(int)

    for terms in data_dict.values():
        for term in terms:
            if terms[term] > 0:
                term_doc_frequency[term] += 1

    tf_idf_dict = {}
    for uri, terms in data_dict.items():
        tf_idf_dict[uri] = {}
        for term, freq in terms.items():
            tf = freq
            idf = math.log(doc_count / (1 + term_doc_frequency[term]))
            tf_idf_dict[uri][term] = tf * idf

    return tf_idf_dict


# Perform Boolean retrieval
def boolean_retrieval(data_dict, query):
    tokens = query.split()
    combined_results = set()

    initial_term = tokens[0].lower()
    if initial_term not in next(iter(data_dict.values())):
        return []

    combined_results = {uri for uri, terms in data_dict.items() if terms.get(initial_term, 0) > 0}
    i = 1

    while i < len(tokens):
        operator = tokens[i].upper()
        term = tokens[i + 1].lower()

        if term not in next(iter(data_dict.values())):
            return []

        term_uris = {uri for uri, terms in data_dict.items() if terms.get(term, 0) > 0}

        if operator == "AND":
            combined_results &= term_uris
        elif operator == "OR":
            combined_results |= term_uris
        elif operator == "NOT":
            combined_results -= term_uris

        i += 2

    return list(combined_results)


# Perform Vector Space Model retrieval
def vsm_retrieval(tf_idf_dict, query):
    query_terms = query.split()
    query_vector = defaultdict(float)

    for term in query_terms:
        query_vector[term.lower()] += 1

    scores = defaultdict(float)
    for uri, terms in tf_idf_dict.items():
        doc_vector = terms
        dot_product = sum(query_vector[term] * doc_vector.get(term, 0) for term in query_vector)
        query_magnitude = math.sqrt(sum(val**2 for val in query_vector.values()))
        doc_magnitude = math.sqrt(sum(val**2 for val in doc_vector.values()))
        if query_magnitude * doc_magnitude != 0:
            scores[uri] = dot_product / (query_magnitude * doc_magnitude)

    sorted_results = sorted(scores.items(), key=lambda x: x[1], reverse=True)

    print("\nVector Space Model Results (Cosine Similarity):")
    print("-" * 40)
    print("{:<6} {:<20} {:<10}".format("Rank", "Document", "Score"))
    print("-" * 40)
    for rank, (doc, score) in enumerate(sorted_results, start=1):
        print("{:<6} {:<20} {:<10.4f}".format(rank, doc, score))
    print("-" * 40)

    return {doc: score for doc, score in sorted_results if score > 0}


# Perform Probabilistic Retrieval
def probabilistic_retrieval(data_dict, query):
    tokens = query.split()
    scores = defaultdict(float)
    doc_count = len(data_dict)

    for term in tokens:
        term = term.lower()
        if term in next(iter(data_dict.values())):
            term_doc_count = sum(1 for terms in data_dict.values() if terms.get(term, 0) > 0)
            idf = math.log((doc_count - term_doc_count + 0.5) / (term_doc_count + 0.5))
            for uri, terms in data_dict.items():
                if terms.get(term, 0) > 0:
                    scores[uri] += idf

    sorted_results = sorted(scores.items(), key=lambda x: x[1], reverse=True)

    # Print the results in a formatted
    print("\nProbabilistic Retrieval Results (Scores):")
    print("-" * 40)
    print("{:<6} {:<20} {:<10}".format("Rank", "Document", "Score"))
    print("-" * 40)
    for rank, (doc, score) in enumerate(sorted_results, start=1):
        print("{:<6} {:<20} {:<10.4f}".format(rank, doc, score))
    print("-" * 40)

    return {doc: score for doc, score in sorted_results if score > 0}

# %% [markdown]
# ## 5. Αξιολόγηση Συστήματος

# %%
# Evaluate the selected retrieval method
def evaluate_results(ground_truth, retrieved):
    # If the given input is a dict, then that means that there are two values contained in it (uri, score).
    # With the use of the .keys() method we can extract the URIs from the dictionary and discard the scores.
    if isinstance(retrieved, dict):
        retrieved = set(retrieved.keys())  # Extract document IDs if retrieved is a dictionary
    else:
        retrieved = set(retrieved)  # Convert list or other iterable to a set

    print("Retrieved Docs: ", retrieved)
    relevant = set(ground_truth)

    # calculate true positives, false positives, and false negatives
    tp = len(retrieved & relevant)  # true positives  - documents that are retrieved and are relevant
    fp = len(retrieved - relevant)  # false positives - documents that are retrieved but are not relevant
    fn = len(relevant - retrieved)  # false negatives - documents that are not retrieved but actually are relevant

    # Calculate precision, recall, and F1-score
    precision = tp / (tp + fp) if (tp + fp) > 0 else 0
    recall = tp / (tp + fn) if (tp + fn) > 0 else 0
    f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

    # Print calculated metrics
    print("\nEvaluation Metrics:")
    print(f"Precision: {precision:.3f}")
    print(f"Recall: {recall:.3f}")
    print(f"F1-Score: {f1_score:.3f}")

query = "musician AND jazz" # form
ground_truth = search_query_dict(data_dict, query)

# Show option to the user
print("\nChoose Retrieval Method:")
print("1. Boolean Retrieval")
print("2. Vector Space Model")
print("3. Probabilistic Retrieval")
choice = int(input("Enter your choice (1/2/3): "))


if choice == 1:
    results = boolean_retrieval(data_dict, query)
    print("\nBoolean Retrieval Results:", results)
    evaluate_results(ground_truth, results)
elif choice == 2:
    # Remove logical operators for VSM
    vsm_query = " ".join([token for token in query.split() if token.upper() not in {"AND", "OR", "NOT"}])
    tf_idf_dict = compute_tf_idf(data_dict)
    results = vsm_retrieval(tf_idf_dict, vsm_query)
    evaluate_results(ground_truth, results)
elif choice == 3:
    # Remove logical operators for Probabilistic Retrieval
    prob_query = " ".join([token for token in query.split() if token.upper() not in {"AND", "OR", "NOT"}])
    results = probabilistic_retrieval(data_dict, prob_query)
    evaluate_results(ground_truth, results)
else:
    print("Invalid choice!")
    results = []
# Out:
# Tokenized query:  ['musician', 'AND', 'jazz']
#
# Choose Retrieval Method:
# 1. Boolean Retrieval
# 2. Vector Space Model
# 3. Probabilistic Retrieval
#
# Vector Space Model Results (Cosine Similarity):
# ----------------------------------------
# Rank   Document             Score
# ----------------------------------------
# 1      http://dbpedia.org/resource/Elizabeth_Shepherd_(musician) 0.2755
# 2      http://dbpedia.org/resource/Mikko_Innanen_(musician) 0.2669
# 3      http://dbpedia.org/resource/Sam_Stephenson_(writer) 0.2423
# 4      http://dbpedia.org/resource/Judy_Carmichael 0.2312
# 5      http://dbpedia.org/resource/Shamek_Farrah 0.2122
# 6      http://dbpedia.org/resource/Gregg_Karukas 0.1632
# 7      http://dbpedia.org/resource/Bob_Havens 0.1378
# 8      http://dbpedia.org/resource/Donny_McCaslin 0.1156
# 9      http://dbpedia.org/resource/Gwyn_Jay_Allen 0.1149
# 10     http://dbpedia.org/resource/Jamie_Shields_(musician) 0.1141
# 11     http://dbpedia.org/resource/Judi_Silvano 0.1138
# 12     http://dbpedia.org/resource/John_Edmondson_(musician) 0.1028
# 13     http://dbpedia.org/resource/Michael_Campbell_(musician_and_actor) 0.0937
# 14     http://dbpedia.org/resource/Chris_Karan 0.0933
# 15     http://dbpedia.org/resource/Tony_Garnier_(musician) 0.0849
# 16     http://dbpedia.org/resource/Chris_Owens_(actor) 0.0751
# 17     http://dbpedia.org/resource/Dudley_Riggs 0.0715
# 18     http://dbpedia.org/resource/Kasia_Kowalska 0.0684
# 19     http://dbpedia.org/resource/Owen_Temple 0.0674
# 20     http://dbpedia.org/resource/Vanessa_Ament 0.0660
# 21     http://dbpedia.org/resource/Eric_Murdock 0.0640
# 22     http://dbpedia.org/resource/Henry_Small_(singer) 0.0628
# 23     http://dbpedia.org/resource/Mei-Ting_Sun 0.0623
# 24     http://dbpedia.org/resource/Martin_Iveson 0.0596
# 25     http://dbpedia.org/resource/Dylan_Cramer 0.0573
# 26     http://dbpedia.org/resource/Faith_Soloway 0.0561
# 27     http://dbpedia.org/resource/Michael_Grepp 0.0479
# 28     http://dbpedia.org/resource/Bruce_Adolphe 0.0474
# 29     http://dbpedia.org/resource/Attila_Pacsay 0.0466
# 30     http://dbpedia.org/resource/Oren_Bloedow 0.0438
# 31     http://dbpedia.org/resource/Greg_Otterholt 0.0413
# 645    http://dbpedia.org/resource/Lewis_Leavitt 0.0000
# 646    http://dbpedia.org/resource/Li_Yuejiu 0.0000
# 647    http://dbpedia.org/resource/Liam_Chilvers 0.0000
# 648    http://dbpedia.org/resource/Lidija_Horvat-Dunjko 0.0000
# 649    http://dbpedia.org/resource/Lisa_Landry 0.0000
# 650    http://dbpedia.org/resource/Logan_Aldridge 0.0000
# 651    http://dbpedia.org/resource/Lorna_Boothe 0.0000
# 652    http://dbpedia.org/resource/Loti_Kobalia 0.0000
# 653    http://dbpedia.org/resource/Lucian_Grainge 0.0000
# 654    http://dbpedia.org/resource/Lucien_Bourjeily 0.0000
# 655    http://dbpedia.org/resource/Luis_Alberto_Monge 0.0000
# 656    http://dbpedia.org/resource/Luis_Gatmaitan 0.0000
# 657    http://dbpedia.org/resource/Luis_Medina_(baseball) 0.0000
# 658    http://dbpedia.org/resource/M._G._Sheftall 0.0000
# 659    http://dbpedia.org/resource/Ma_Junren 0.0000
# 660    http://dbpedia.org/resource/Maha_el-Samnah 0.0000
# 661    http://dbpedia.org/resource/Mammootty 0.0000
# 662    http://dbpedia.org/resource/Manju_Malhi 0.0000
# 663    http://dbpedia.org/resource/Manny_Pacquiao 0.0000
# 664    http://dbpedia.org/resource/Marat_Dzhumaev 0.0000
# 665    http://dbpedia.org/resource/Marc_Butan 0.0000
# 666    http://dbpedia.org/resource/Marc_Fleury 0.0000
# 667    http://dbpedia.org/resource/Marc_Logan 0.0000
# 668    http://dbpedia.org/resource/Marc_Wauters 0.0000
# 669    http://dbpedia.org/resource/Marcus_Vick 0.0000
# 670    http://dbpedia.org/resource/Marek_Antoni_Nowicki 0.0000
# 671    http://dbpedia.org/resource/Marek_Janowski 0.0000
# 672    http://dbpedia.org/resource/Maria_de_Lourdes_Martins_Cruz 0.0000
# 673    http://dbpedia.org/resource/Marilyn_Hall_Patel 0.0000
# 674    http://dbpedia.org/resource/Mario_Michel 0.0000
# 675    http://dbpedia.org/resource/Mark_Benecke 0.0000
# 676    http://dbpedia.org/resource/Mark_Boswell_(film_director) 0.0000
# 677    http://dbpedia.org/resource/Mark_Breslin 0.0000
# 678    http://dbpedia.org/resource/Mark_Carlson_(quarterback) 0.0000
# 679    http://dbpedia.org/resource/Mark_Denton 0.0000
# 680    http://dbpedia.org/resource/Mark_Jones_(rugby,_born_1979) 0.0000
# 681    http://dbpedia.org/resource/Mark_Juergensmeyer 0.0000
# 682    http://dbpedia.org/resource/Mark_Kirchner 0.0000
# 683    http://dbpedia.org/resource/Mark_Poepping 0.0000
# 684    http://dbpedia.org/resource/Mark_Tatge 0.0000
# 685    http://dbpedia.org/resource/Marlon_Magtira 0.0000
# 686    http://dbpedia.org/resource/Martha_Wash 0.0000
# 687    http://dbpedia.org/resource/Martha_Williamson 0.0000
# 688    http://dbpedia.org/resource/Martin_A._Lee 0.0000
# 689    http://dbpedia.org/resource/Martin_Allen_(writer) 0.0000
# 690    http://dbpedia.org/resource/Martin_Edward_Stephenson 0.0000
# 691    http://dbpedia.org/resource/Mary_Ann_Lila 0.0000
# 692    http://dbpedia.org/resource/Mary_Fitzgerald_(artist) 0.0000
# 693    http://dbpedia.org/resource/Mary_Goldring 0.0000
# 694    http://dbpedia.org/resource/Massimo_Milano 0.0000
# 695    http://dbpedia.org/resource/Mathias_Woo 0.0000
# 696    http://dbpedia.org/resource/Matt_Oppenheim 0.0000
# 697    http://dbpedia.org/resource/Maurice_Swan 0.0000
# 698    http://dbpedia.org/resource/Mauro_Baldi 0.0000
# 699    http://dbpedia.org/resource/Mayuko_Irie 0.0000
# 700    http://dbpedia.org/resource/McWilliams_Arroyo 0.0000
# 701    http://dbpedia.org/resource/Meddy_Ford 0.0000
# 702    http://dbpedia.org/resource/Meena_Lee 0.0000
# 703    http://dbpedia.org/resource/Meir_Margalit 0.0000
# 704    http://dbpedia.org/resource/Melissa_Trainer 0.0000
# 705    http://dbpedia.org/resource/Menachem_Z._Rosensaft 0.0000
# 706    http://dbpedia.org/resource/Meredith_Braun 0.0000
# 707    http://dbpedia.org/resource/Mervyn_C._Alleyne 0.0000
# 708    http://dbpedia.org/resource/Michael_Coogan 0.0000
# 709    http://dbpedia.org/resource/Michael_L._Gross_(chemist) 0.0000
# 710    http://dbpedia.org/resource/Michael_Mikhail 0.0000
# 711    http://dbpedia.org/resource/Michael_Petrelis 0.0000
# 712    http://dbpedia.org/resource/Michael_Rowe_(director) 0.0000
# 713    http://dbpedia.org/resource/Michael_S._Bernick 0.0000
# 714    http://dbpedia.org/resource/Michael_Waller 0.0000
# 715    http://dbpedia.org/resource/Michal_Opas 0.0000
# 716    http://dbpedia.org/resource/Michel_Che 0.0000
# 717    http://dbpedia.org/resource/Michelle_Ye 0.0000
# 718    http://dbpedia.org/resource/Mick_Jackson_(singer) 0.0000
# 719    http://dbpedia.org/resource/Mick_O'Brien_(footballer,_born_1979) 0.0000
# 720    http://dbpedia.org/resource/Mihai_Apostol 0.0000
# 721    http://dbpedia.org/resource/Mike_Burton_(rugby_union) 0.0000
# 722    http://dbpedia.org/resource/Mike_Caldwell_(baseball) 0.0000
# 723    http://dbpedia.org/resource/Mike_LaValliere 0.0000
# 724    http://dbpedia.org/resource/Mike_Pandey 0.0000
# 725    http://dbpedia.org/resource/Mike_Powell_(journalist) 0.0000
# 726    http://dbpedia.org/resource/Mike_Smartt 0.0000
# 727    http://dbpedia.org/resource/Mike_Trebilcock 0.0000
# 728    http://dbpedia.org/resource/Mikio_Sato 0.0000
# 729    http://dbpedia.org/resource/Milva 0.0000
# 730    http://dbpedia.org/resource/Mindaugas_Murza 0.0000
# 731    http://dbpedia.org/resource/Mirella_Parutto 0.0000
# 732    http://dbpedia.org/resource/Miriam_Gross 0.0000
# 733    http://dbpedia.org/resource/Misa_Telefoni_Retzlaff 0.0000
# 734    http://dbpedia.org/resource/Mitzi_McCall 0.0000
# 735    http://dbpedia.org/resource/Moana_Jackson 0.0000
# 736    http://dbpedia.org/resource/Mohamed_Salah_El_Azab 0.0000
# 737    http://dbpedia.org/resource/Mohammad_Nabi_Omari 0.0000
# 738    http://dbpedia.org/resource/Monte_Cassim 0.0000
# 739    http://dbpedia.org/resource/Murtaza_Ahmed_Khan 0.0000
# 740    http://dbpedia.org/resource/Myra_(singer) 0.0000
# 741    http://dbpedia.org/resource/Nagwa_Fouad 0.0000
# 742    http://dbpedia.org/resource/Nancy_Ames 0.0000
# 743    http://dbpedia.org/resource/Nancy_Kemp-Arendt 0.0000
# 744    http://dbpedia.org/resource/Nancy_Loo 0.0000
# 745    http://dbpedia.org/resource/Naomi_Watts 0.0000
# 746    http://dbpedia.org/resource/Natalia_Kills 0.0000
# 747    http://dbpedia.org/resource/Nathan_Lyon_(chef) 0.0000
# 748    http://dbpedia.org/resource/Nathan_Runkle 0.0000
# 749    http://dbpedia.org/resource/Neeraj_Patil 0.0000
# 750    http://dbpedia.org/resource/Neil_Cossons 0.0000
# 751    http://dbpedia.org/resource/Neil_Fallon 0.0000
# 752    http://dbpedia.org/resource/Neil_Landau 0.0000
# 753    http://dbpedia.org/resource/Neil_Whitworth 0.0000
# 754    http://dbpedia.org/resource/Nella_Cotrupi 0.0000
# 755    http://dbpedia.org/resource/Niall_McGarry 0.0000
# 756    http://dbpedia.org/resource/Nicholas_Doumanis 0.0000
# 757    http://dbpedia.org/resource/Nicholas_de_Jongh 0.0000
# 758    http://dbpedia.org/resource/Nick_Baines_(bishop) 0.0000
# 759    http://dbpedia.org/resource/Nicky_Reid 0.0000
# 760    http://dbpedia.org/resource/Nicole_Kidman 0.0000
# 761    http://dbpedia.org/resource/Nino_Escalera 0.0000
# 762    http://dbpedia.org/resource/Nivio_Ziviani 0.0000
# ...
# 809    http://dbpedia.org/resource/Rajiva_Wijesinha 0.0000
# 810    http://dbpedia.org/resource/Ralph_Iwowari 0.0000
# 811    http://dbpedia.org/resource/Ramachandra_Gowda 0.0000
# 812    http://dbpedia.org/resource/Ramazan_Rragami 0.0000
# 813    http://dbpedia.org/resource/Ramiro_Choc 0.0000
# 814    http://dbpedia.org/resource/Ramiro_Torres 0.0000
# 815    http://dbpedia.org/resource/Randal_Quarles 0.0000
# 816    http://dbpedia.org/resource/Randy_Brown_(American_football) 0.0000
# 817    http://dbpedia.org/resource/Rashid_Gaysanov 0.0000
# 818    http://dbpedia.org/resource/Rassie_Erasmus 0.0000
# 819    http://dbpedia.org/resource/Ray_Crooke 0.0000
# 820    http://dbpedia.org/resource/Ray_MacDonnell 0.0000
# 821    http://dbpedia.org/resource/Ray_Sansom 0.0000
# 822    http://dbpedia.org/resource/Raymundo_Perdigon_Brito 0.0000
# 823    http://dbpedia.org/resource/Rebecca_Northan 0.0000
# 824    http://dbpedia.org/resource/Reed_St._Mark 0.0000
# 825    http://dbpedia.org/resource/Renny_Pritikin 0.0000
# 826    http://dbpedia.org/resource/Rhyll_McMaster 0.0000
# 827    http://dbpedia.org/resource/Rhys_O'Keeffe 0.0000
# 828    http://dbpedia.org/resource/Rich_Bordi 0.0000
# 829    http://dbpedia.org/resource/Richard_Allen_Davis 0.0000
# 830    http://dbpedia.org/resource/Richard_Chen 0.0000
# 831    http://dbpedia.org/resource/Richard_Goode 0.0000
# 832    http://dbpedia.org/resource/Richard_Green_(golfer) 0.0000
# 880    http://dbpedia.org/resource/Saxby_Chambliss 0.0000
# 881    http://dbpedia.org/resource/Scott_Guyett 0.0000
# 882    http://dbpedia.org/resource/Scott_Oki 0.0000
# 883    http://dbpedia.org/resource/Scott_Sandage 0.0000
# 884    http://dbpedia.org/resource/Scott_Shane 0.0000
# 885    http://dbpedia.org/resource/Sean_McAdam_(journalist) 0.0000
# 886    http://dbpedia.org/resource/Seiko_Lee 0.0000
# 887    http://dbpedia.org/resource/Sekou_Odinga 0.0000
# 888    http://dbpedia.org/resource/Serge_Lourie 0.0000
# 889    http://dbpedia.org/resource/Shaka_Hislop 0.0000
# 890    http://dbpedia.org/resource/Shane_Valenti 0.0000
# 891    http://dbpedia.org/resource/Shaun_Caton 0.0000
# 892    http://dbpedia.org/resource/Shaun_Duggan 0.0000
# 893    http://dbpedia.org/resource/Shirley_Erena_Murray 0.0000
# 894    http://dbpedia.org/resource/ShyBoy 0.0000
# 895    http://dbpedia.org/resource/Sophie_Crumb 0.0000
# 896    http://dbpedia.org/resource/Spencer_Trethewy 0.0000
# 897    http://dbpedia.org/resource/Stan_Papi 0.0000
# 898    http://dbpedia.org/resource/Stefaan_Verhulst 0.0000
# 899    http://dbpedia.org/resource/Stefan_Weber_(musician) 0.0000
# 900    http://dbpedia.org/resource/Stephen_Cassidy 0.0000
# 901    http://dbpedia.org/resource/Stephen_Evans_(actor) 0.0000
# 902    http://dbpedia.org/resource/Stephen_J_Smith 0.0000
# 903    http://dbpedia.org/resource/Stephen_Raudenbush 0.0000
# 904    http://dbpedia.org/resource/Steve_Castle 0.0000
# 905    http://dbpedia.org/resource/Steve_Rivkin 0.0000
# 906    http://dbpedia.org/resource/Steve_Rosenthal 0.0000
# 907    http://dbpedia.org/resource/Steven_Ferguson 0.0000
# 908    http://dbpedia.org/resource/Steven_Marrs 0.0000
# 909    http://dbpedia.org/resource/Steven_Point 0.0000
# 910    http://dbpedia.org/resource/Steven_Weil 0.0000
# 911    http://dbpedia.org/resource/Sua_Rimoni_Ah_Chong 0.0000
# 912    http://dbpedia.org/resource/Suren_Dutia 0.0000
# 913    http://dbpedia.org/resource/Susan_Akin 0.0000
# 914    http://dbpedia.org/resource/Susan_Christie 0.0000
# 915    http://dbpedia.org/resource/Susan_Westerberg_Prager 0.0000
# 916    http://dbpedia.org/resource/Susanne_Pumper 0.0000
# 917    http://dbpedia.org/resource/Sylvain_Ngabu_Chumbu 0.0000
# 918    http://dbpedia.org/resource/Sylvie_Roy 0.0000
# 919    http://dbpedia.org/resource/Takayuki_Hattori 0.0000
# 920    http://dbpedia.org/resource/Tamara_Awerbuch-Friedlander 0.0000
# 921    http://dbpedia.org/resource/Tana_Umaga 0.0000
# 922    http://dbpedia.org/resource/Tang_Fong_Har 0.0000
# 923    http://dbpedia.org/resource/Tania_Libertad 0.0000
# 924    http://dbpedia.org/resource/Tantely_Andrianarivo 0.0000
# 925    http://dbpedia.org/resource/Tate_Forcier 0.0000
# 926    http://dbpedia.org/resource/Taylor_Townsend_(politician) 0.0000
# 927    http://dbpedia.org/resource/Ted_Henrys 0.0000
# 928    http://dbpedia.org/resource/Ted_Hill_(mathematician) 0.0000
# 929    http://dbpedia.org/resource/Terry_Wogan 0.0000
# 930    http://dbpedia.org/resource/Tevian_Dray 0.0000
# 931    http://dbpedia.org/resource/The_Taylan_Brothers 0.0000
# 932    http://dbpedia.org/resource/The_Zombie_Kids 0.0000
# 933    http://dbpedia.org/resource/Thom_Wolf 0.0000
# 934    http://dbpedia.org/resource/Thomas_B._Hayward 0.0000
# 935    http://dbpedia.org/resource/Thomas_Gaffey 0.0000
# 936    http://dbpedia.org/resource/Thomas_Hampson_(baritone) 0.0000
# 937    http://dbpedia.org/resource/Thomas_McCarthy_(poet) 0.0000
# 938    http://dbpedia.org/resource/Tim_Evans 0.0000
# 939    http://dbpedia.org/resource/Timothy_Grucza 0.0000
# 940    http://dbpedia.org/resource/Tobias_Frere-Jones 0.0000
# 941    http://dbpedia.org/resource/Todd_Parnell 0.0000
# 942    http://dbpedia.org/resource/Tom_Baxter 0.0000
# 943    http://dbpedia.org/resource/Tom_Bradley_(author) 0.0000
# 944    http://dbpedia.org/resource/Tom_Drury 0.0000
# 945    http://dbpedia.org/resource/Tom_Jurich 0.0000
# 946    http://dbpedia.org/resource/Tom_Long_(politician) 0.0000
# 947    http://dbpedia.org/resource/Tom_Noddy 0.0000
# 948    http://dbpedia.org/resource/Tom_O'Donnell 0.0000
# 949    http://dbpedia.org/resource/Tom_Wilson_(2000s_catcher) 0.0000
# 950    http://dbpedia.org/resource/Tommy_Ohlsson 0.0000
# 951    http://dbpedia.org/resource/Tony_Beasley 0.0000
# 952    http://dbpedia.org/resource/Tony_Ghelfi 0.0000
# 953    http://dbpedia.org/resource/Tony_Johnson_(soccer) 0.0000
# 954    http://dbpedia.org/resource/Tony_Lundon 0.0000
# 955    http://dbpedia.org/resource/Tony_Mordente 0.0000
# 956    http://dbpedia.org/resource/Travis_Keller 0.0000
# 957    http://dbpedia.org/resource/Trevor_Benjamin 0.0000
# 958    http://dbpedia.org/resource/Trevor_Ferguson 0.0000
# 959    http://dbpedia.org/resource/Trevor_Grove 0.0000
# 960    http://dbpedia.org/resource/Tsuyoshi_Yamaguchi 0.0000
# 961    http://dbpedia.org/resource/Tyshane 0.0000
# 962    http://dbpedia.org/resource/Ulf-Dietrich_Reips 0.0000
# 963    http://dbpedia.org/resource/Ulrich_Schulze 0.0000
# 964    http://dbpedia.org/resource/Utpal_Bhattacharya 0.0000
# 965    http://dbpedia.org/resource/V._Viswanatha_Menon 0.0000
# 966    http://dbpedia.org/resource/Va'ai_Papu_Vailupe 0.0000
# 967    http://dbpedia.org/resource/Vasco_Uva 0.0000
# 968    http://dbpedia.org/resource/Vasil_Sikharulidze 0.0000
# 969    http://dbpedia.org/resource/Ventimiglia_Giovanni 0.0000
# 970    http://dbpedia.org/resource/Vic_Stasiuk 0.0000
# 971    http://dbpedia.org/resource/Victor_Clube 0.0000
# 972    http://dbpedia.org/resource/Vikram_(actor) 0.0000
# 973    http://dbpedia.org/resource/Viktoriya_Yermolyeva 0.0000
# 974    http://dbpedia.org/resource/Viliami_Toluta'u 0.0000
